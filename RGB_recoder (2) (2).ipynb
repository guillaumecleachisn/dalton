# %%
import PIL

# %% [markdown]
# <img src="img/kingfisher.jpg" alt="mesange image" title="Une jeune mésange bleu" width="50%">

# %%
from PIL import Image
img = Image.open("img/kingfisher.jpg")

# %% [markdown]
# ce code nous laise modifier l'image pixel par pixel:
# 1. le code commance au pixel en haut a gauche
# 2. il enregistre la valeur du rouge du vert et du bleu
# 3. il calcule aussi d'autre chause tell que la valeur du gris et la valeur maxilmal et minimal
# 4. il inject en suite de nouvelles valeurs RGB dans le pixel
# 5. il va au prochin pixel a droit et fait la meme chause
# 6. quand il arive au bout de ligne il se rement au debut dans la prochaine colonne

# %%
Xmax=(img.size)[0]
Ymax=(img.size)[1]
y=0
while y<Ymax :
    x=0
    while x<Xmax :
        red=img.getpixel((x,y))[0]
        green=img.getpixel((x,y))[1]
        blue=img.getpixel((x,y))[2]
        grey=round(green*0.21+blue*0.72+red*0.07)
        cmin=min(red,blue,green)
        cmax=max(red,blue,green)
        img.putpixel((x,y),(red,green,cmin))
        x+=1
    y+=1

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x7F8271FDC828>

# %%
from PIL import Image
img = Image.open("img/kingfisher.jpg")

# %%
Xmax=(img.size)[0]
Ymax=(img.size)[1]
y=0
while y<Ymax :
    x=0
    while x<Xmax :
        red=img.getpixel((x,y))[0]
        green=img.getpixel((x,y))[1]
        blue=img.getpixel((x,y))[2]
        img.putpixel((x,y),(red,green,0))
        x+=1
    y+=1

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x7F8271FDC1D0>

# %%
from PIL import Image
img = Image.open("img/kingfisher.jpg")

# %%
Xmax=(img.size)[0]
Ymax=(img.size)[1]
y=0
while y<Ymax :
    x=0
    while x<Xmax :
        red=img.getpixel((x,y))[0]
        green=img.getpixel((x,y))[1]
        blue=img.getpixel((x,y))[2]
        grey=round(green*0.21+blue*0.72+red*0.07)
        cmin=min(red,blue,green)
        cmax=max(red,blue,green)
        img.putpixel((x,y),(red,green,cmin))
        x+=1
    y+=1

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x7F8271FDCEF0>

# %%
from PIL import Image
img = Image.open("img/kingfisher.jpg")

# %%
Xmax=(img.size)[0]
Ymax=(img.size)[1]
y=0
while y<Ymax :
    x=0
    while x<Xmax :
        RGBred=img.getpixel((x,y))[0]
        RGBgreen=img.getpixel((x,y))[1]
        RGBblue=img.getpixel((x,y))[2]
        
        XYZred=int(0.431*RGBred+0.342*RGBgreen+0.178*RGBblue)
        XYZgreen=int(0.222*RGBred+0.707*RGBgreen+0.071*RGBblue)
        XYZblue=int(0.222*RGBred+0.707*RGBgreen+0.071*RGBblue)
        img.putpixel((x,y),(XYZred,XYZgreen,0))
        x+=1
    y+=1
# Out:
# 199 204 204
# 199 204 204
# 199 204 204
# 199 204 204
# 200 205 205
# 200 205 205
# 200 205 205
# 200 205 205
# 199 204 204
# 200 205 205
# 200 205 205
# 200 205 205
# 200 206 206
# 200 205 205
# 200 205 205
# 200 205 205
# 199 205 205
# 173 188 188
# 171 187 187
# 171 187 187
# 171 187 187
# 171 187 187
# 171 187 187
# 171 187 187
# 171 187 187
# 170 186 186
# 170 186 186
# 170 187 187
# 170 187 187
# 170 187 187
# 170 187 187
# 170 187 187
# 170 187 187
# 170 187 187
# 170 187 187
# 170 187 187
# 169 186 186
# 169 186 186
# 169 186 186
# 169 186 186
# 169 186 186
# 169 186 186
# 169 186 186
# 169 186 186
# 169 186 186
# 169 186 186
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 166 184 184
# 166 184 184
# 166 184 184
# 167 185 185
# 167 185 185
# 166 184 184
# 166 185 185
# 166 185 185
# 166 185 185
# 166 185 185
# 166 185 185
# 166 185 185
# 166 185 185
# 166 185 185
# 166 185 185
# 166 185 185
# 166 184 184
# 166 184 184
# 166 184 184
# 166 184 184
# 166 184 184
# 166 184 184
# 166 184 184
# 167 185 185
# 167 185 185
# 167 185 185
# 166 184 184
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 168 186 186
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 168 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 167 185 185
# 169 186 186
# 169 186 186
# 169 186 186
# 169 186 186
# 169 186 186
# 169 186 186
# 169 186 186
# 169 186 186
# 170 186 186
# 169 185 185
# 169 185 185
# 169 185 185
# 169 185 185
# 169 185 185
# 169 185 185
# 169 185 185
# 169 185 185
# 169 185 185
# 169 185 185
# 169 185 185
# 169 185 185
# 169 185 185
# 169 185 185
# 169 185 185
# 169 185 185
# 169 185 185
# 169 185 185
# 168 184 184
# 168 184 184
# 169 185 185
# 169 185 185
# 169 185 185
# 169 185 185
# 168 184 184
# 168 184 184
# 168 184 184
# 169 185 185
# 169 185 185
# 168 184 184
# 168 184 184
# 168 184 184
# 168 184 184
# 168 184 184
# 168 184 184
# 168 184 184
# 168 184 184
# 168 184 184
# 168 184 184
# 167 183 183
# 167 183 183
# 167 183 183
# 167 183 183
# 166 182 182
# 166 182 182
# 166 182 182
# 166 182 182
# 167 182 182
# 167 182 182
# 167 182 182
# 167 182 182
# 166 181 181
# 166 181 181
# 165 180 180
# 165 180 180
# 164 179 179
# 164 179 179
# 164 179 179
# 164 179 179
# 164 179 179
# 165 180 180
# 165 180 180
# 165 180 180
# 164 179 179
# 164 179 179
# 164 179 179
# 163 178 178
# 163 178 178
# 163 178 178
# 163 178 178
# 163 178 178
# 163 178 178
# 163 178 178

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x7F438A93EAC8>

# %%
from PIL import Image
img = Image.open("img/kingfisher.jpg")

# %%
Xmax=(img.size)[0]
Ymax=(img.size)[1]
y=0
while y<Ymax :
    x=0
    while x<Xmax :
        RGBred=img.getpixel((x,y))[0]
        RGBgreen=img.getpixel((x,y))[1]
        RGBblue=img.getpixel((x,y))[2]
        
        XYZred=int(0.431*RGBred+0.342*RGBgreen+0.178*RGBblue)
        XYZgreen=int(0.222*RGBred+0.707*RGBgreen+0.071*RGBblue)
        XYZblue=int(0.222*RGBred+0.707*RGBgreen+0.071*RGBblue)
        XYZgrey=round(XYZgreen*0.21+XYZblue*0.72+XYZred*0.07)
        XYZcmin=min(XYZred,XYZblue,XYZgreen)
        XYZcmax=max(XYZred,XYZblue,XYZgreen)
        img.putpixel((x,y),(XYZred,XYZgreen,XYZcmin))
        x+=1
    y+=1

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x426 at 0x7F438A95EAC8>
